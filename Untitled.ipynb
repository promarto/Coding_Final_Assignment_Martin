# %%
import pandas as pd
import numpy as np
import warnings

# %%
df.read.csv(hotels-vienna.csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 df.read.csv(hotels-vienna.csv)
#
# NameError: name 'df' is not defined

# %%
data_set = pd.read_csv("http://localhost:8888/edit/clean/hotels-vienna.csv", encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 data_set = pd.read_csv("http://localhost:8888/edit/clean/hotels-vienna.csv", encoding="utf-8")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
data_set = pd.read_csv("hotels-vienna.csv", encoding="utf-8")

# %%
data_set = pd.read_csv("hotels-vienna.csv", encoding="utf-8") # that is for reading csv file format

# %%
data_set.describe().transpose() #making a statistical table
# Out:
#                 count          mean         std      min       25%      50%  \
# rating_count    393.0    155.048346  191.217435      1.0     27.00     84.0
# price           428.0    131.366822   91.580545     27.0     83.00    109.5
# stars           428.0      3.434579    0.772278      1.0      3.00      3.5
# ratingta        325.0      3.990769    0.482638      2.0      3.50      4.0
# ratingta_count  325.0    556.516923  586.874582      2.0    129.00    335.0
# scarce_room     428.0      0.598131    0.490850      0.0      0.00      1.0
# hotel_id        428.0  22153.502336  146.858477  21894.0  22027.75  22155.5
# offer           428.0      0.679907    0.467058      0.0      0.00      1.0
# year            428.0   2017.000000    0.000000   2017.0   2017.00   2017.0
# month           428.0     11.000000    0.000000     11.0     11.00     11.0
# weekend         428.0      0.000000    0.000000      0.0      0.00      0.0
# ...

# %%
data_set.filter(["price", "stars", "distance"]).describe().transpose()
# Out:
#           count        mean        std   min   25%    50%    75%     max
# price     428.0  131.366822  91.580545  27.0  83.0  109.5  146.0  1012.0
# stars     428.0    3.434579   0.772278   1.0   3.0    3.5    4.0     5.0
# distance  428.0    1.658879   1.595673   0.0   0.7    1.3    2.0    13.0

# %%
data_set.shape
# first looking at the number of observations and variables before dropping missing values
# Out:
# (428, 24)

# %%
data_set["rating"].isnull().sum() # seeing how many missing values there are
# Out:
# 35

# %%
data_set.loc[data_set["rating"].isnull()] # showing them in their category
# Out:
#      country city_actual  rating_count center1label center2label  \
# 9    Austria      Vienna           NaN  City centre    Donauturm
# 14   Austria      Vienna           NaN  City centre    Donauturm
# 19   Austria      Vienna           NaN  City centre    Donauturm
# 33   Austria      Vienna           NaN  City centre    Donauturm
# 45   Austria      Vienna           NaN  City centre    Donauturm
# 66   Austria      Vienna           NaN  City centre    Donauturm
# 75   Austria      Vienna           NaN  City centre    Donauturm
# 76   Austria      Vienna           NaN  City centre    Donauturm
# 82   Austria      Vienna           NaN  City centre    Donauturm
# 83   Austria      Vienna           NaN  City centre    Donauturm
# 84   Austria      Vienna           NaN  City centre    Donauturm
# 85   Austria      Vienna           NaN  City centre    Donauturm
# 97   Austria      Vienna           NaN  City centre    Donauturm
# ...

# %%
data_set = data_set.loc[data_set["rating"].notnull()] # removing the missing values from rating category

# %%
data_set["rating"].isnull().sum()
# Out:
# 0

# %%
data_set.shape
# Out:
# (393, 24)

# %%
data_set.duplicated().sum() # here we're checking if there are duplicates
# Out:
# 0

# %%
data_set.drop(
    columns=[
        "weekend",
        "month",
        "holiday",
    ],
    inplace=True,
)
# dropping some variables

# %%
data_set.describe().transpose()
# Out:
#                 count          mean         std      min      25%      50%  \
# rating_count    393.0    155.048346  191.217435      1.0     27.0     84.0
# price           393.0    127.659033   89.947495     27.0     82.0    107.0
# stars           393.0      3.441476    0.795642      1.0      3.0      3.5
# ratingta        322.0      3.996894    0.465297      2.5      3.5      4.0
# ratingta_count  322.0    561.453416  587.351683      2.0    136.5    340.5
# scarce_room     393.0      0.564885    0.496404      0.0      0.0      1.0
# hotel_id        393.0  22159.730280  147.554948  21894.0  22034.0  22162.0
# offer           393.0      0.727735    0.445693      0.0      0.0      1.0
# year            393.0   2017.000000    0.000000   2017.0   2017.0   2017.0
# distance        393.0      1.707379    1.626541      0.0      0.8      1.4
# distance_alter  393.0      3.755471    1.663420      0.6      2.7      3.4
# ...

# %%
new = data_set.columns.tolist()
print(new)
# Out:
# ['country', 'city_actual', 'rating_count', 'center1label', 'center2label', 'neighbourhood', 'price', 'city', 'stars', 'ratingta', 'ratingta_count', 'scarce_room', 'hotel_id', 'offer', 'offer_cat', 'year', 'distance', 'distance_alter', 'accommodation_type', 'nnights', 'rating']

# %%
for hotel_id, stars in zip(data_set['hotel_id'], data_set['stars']):
    if stars >= 4:
        print(f"{hotel_id} is luxurious")
    else:
        print(f"{hotel_id} isn't luxurious")
# creating a loop through hotel_id and stars
# Out:
# 21894 is luxurious
# 21897 is luxurious
# 21901 is luxurious
# 21902 isn't luxurious
# 21903 is luxurious
# 21904 is luxurious
# 21906 is luxurious
# 21907 is luxurious
# 21908 isn't luxurious
# 21912 is luxurious
# 21913 is luxurious
# 21914 is luxurious
# 21915 isn't luxurious
# 21917 is luxurious
# 21918 isn't luxurious
# 21919 isn't luxurious
# 21920 isn't luxurious
# 21922 isn't luxurious
# 21924 isn't luxurious
# 21925 isn't luxurious
# 21926 is luxurious
# 21927 isn't luxurious
# 21928 isn't luxurious
# 21930 is luxurious
# 21933 isn't luxurious
# 21934 isn't luxurious
# 21935 isn't luxurious
# 21936 isn't luxurious
# 21937 isn't luxurious
# 21938 isn't luxurious
# 21940 isn't luxurious
# 21941 isn't luxurious
# 21943 isn't luxurious
# 21945 isn't luxurious
# 21946 is luxurious
# 21947 isn't luxurious
# 21948 isn't luxurious
# 21949 isn't luxurious
# 21950 isn't luxurious
# 21951 isn't luxurious
# 21956 isn't luxurious
# 21959 is luxurious
# 21960 isn't luxurious
# ...

# %%
data_set.rating.hist() # we create a histogram
# Out:
# <AxesSubplot:>

# %%
data_set.to_csv("hotels-vienna.csv", index=False) # SAVING THE CODE
